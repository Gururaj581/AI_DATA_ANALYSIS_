# %% [markdown]
# ### Task 1: Validate Data with a Custom Expectation in Great Expectations
# **Description**: Create a custom expectation and validate data with Great Expectations.
#
# **Load a sample DataFrame**
#
# data = {
# 'age': [25, 30, 35, 40, 45],
# 'income': [50000, 60000, 75000, None, 100000]
# }

# %%
# Write your code from here
import pandas as pd
from great_expectations.validator.validator import Validator
from great_expectations.expectations.expectation import ExpectationConfiguration
from great_expectations.core.batch import Batch
from great_expectations.core.batch import BatchRequest, RuntimeBatchRequest
from great_expectations.data_context import get_context

data={'age':[25,30,35,40,45],'income':[50000,60000,75000,None,100000]}
df=pd.DataFrame(data)
context=get_context()
batch_request=RuntimeBatchRequest(
    datasource_name="my_pandas_datasource",
    data_connector_name="default_runtime_data_connector_name",
    data_asset_name="test_asset",
    runtime_parameters={"batch_data": df},
    batch_identifiers={"default_identifier_name": "default_id"}
)
validator=context.get_validator(batch_request=batch_request)
result=validator.expect_column_values_to_not_be_null("income")
print(result)
# Out:
# Error while processing DataContextConfig: validation_operators notebooks evaluation_parameter_store_name validations_store_name datasources anonymous_usage_statistics
# Encountered errors during loading config.  See ValidationError for more details.
# ---------------------------------------------------------------------------
# InvalidDataContextConfigError             Traceback (most recent call last)
# Cell In[3], line 11
#       9 data={'age':[25,30,35,40,45],'income':[50000,60000,75000,None,100000]}
#      10 df=pd.DataFrame(data)
# ---> 11 context=get_context()
#      12 batch_request=RuntimeBatchRequest(
#      13     datasource_name="my_pandas_datasource",
#      14     data_connector_name="default_runtime_data_connector_name",
#    (...)
#      17     batch_identifiers={"default_identifier_name": "default_id"}
#      18 )
#      19 validator=context.get_validator(batch_request=batch_request)
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/context_factory.py:593, in get_context(project_config, context_root_dir, project_root_dir, runtime_environment, cloud_base_url, cloud_access_token, cloud_organization_id, cloud_mode, user_agent_str, mode)
#     508 @public_api
#     509 def get_context(  # noqa: PLR0913 # FIXME CoP
#     510     project_config: DataContextConfig | Mapping | None = None,
#    (...)
#     519     mode: ContextModes | None = None,
#     520 ) -> AbstractDataContext:
#     521     """Method to return the appropriate Data Context depending on parameters and environment.
#     522
#     523     Usage:
#    (...)
#     591         GXCloudConfigurationError: Cloud mode enabled, but missing configuration.
#     592     """  # noqa: E501 # FIXME CoP
# --> 593     return project_manager.get_project(
#     594         project_config=project_config,
#     595         context_root_dir=context_root_dir,
#     596         project_root_dir=project_root_dir,
#     597         runtime_environment=runtime_environment,
#     598         cloud_base_url=cloud_base_url,
#     599         cloud_access_token=cloud_access_token,
#     600         cloud_organization_id=cloud_organization_id,
#     601         cloud_mode=cloud_mode,
#     602         user_agent_str=user_agent_str,
#     603         mode=mode,
#     604     )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/context_factory.py:77, in ProjectManager.get_project(self, project_config, context_root_dir, project_root_dir, runtime_environment, cloud_base_url, cloud_access_token, cloud_organization_id, cloud_mode, user_agent_str, mode)
#      64 def get_project(  # noqa: PLR0913 # FIXME CoP
#      65     self,
#      66     project_config: DataContextConfig | Mapping | None = None,
#    (...)
#      75     mode: ContextModes | None = None,
#      76 ) -> AbstractDataContext:
# ---> 77     self.__project = self._build_context(
#      78         project_config=project_config,
#      79         context_root_dir=context_root_dir,
#      80         project_root_dir=project_root_dir,
#      81         runtime_environment=runtime_environment,
#      82         cloud_base_url=cloud_base_url,
#      83         cloud_access_token=cloud_access_token,
#      84         cloud_organization_id=cloud_organization_id,
#      85         cloud_mode=cloud_mode,
#      86         user_agent_str=user_agent_str,
#      87         mode=mode,
#      88     )
#      89     return self.__project
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/context_factory.py:248, in ProjectManager._build_context(self, project_config, context_root_dir, project_root_dir, runtime_environment, cloud_base_url, cloud_access_token, cloud_organization_id, cloud_mode, user_agent_str, mode)
#     240 context_fn_map: dict[ContextModes | None, Callable] = {
#     241     "ephemeral": self._get_ephemeral_context,
#     242     "file": self._get_file_context,
#     243     "cloud": self._get_cloud_context,
#     244     None: self._get_default_context,
#     245 }
#     247 context_fn = context_fn_map[mode]
# --> 248 context = context_fn(**kwargs)
#     250 expected_type = expected_ctx_types[mode]
#     251 if not isinstance(context, expected_type):
#     252     # example I want an ephemeral context but the presence of a GX_CLOUD env var gives me a cloud context  # noqa: E501 # FIXME CoP
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/context_factory.py:291, in ProjectManager._get_default_context(self, project_config, context_root_dir, project_root_dir, runtime_environment, cloud_base_url, cloud_access_token, cloud_organization_id, user_agent_str, cloud_mode, mode)
#     288     return cloud_context
#     290 # Second, check for a context_root_dir to determine if using a filesystem
# --> 291 file_context = self._get_file_context(
#     292     project_config=project_config,
#     293     context_root_dir=context_root_dir,
#     294     project_root_dir=project_root_dir,
#     295     runtime_environment=runtime_environment,
#     296     user_agent_str=user_agent_str,
#     297 )
#     298 if file_context:
#     299     return file_context
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/context_factory.py:380, in ProjectManager._get_file_context(self, project_config, context_root_dir, project_root_dir, runtime_environment, user_agent_str)
#     377 from great_expectations.data_context.data_context import FileDataContext
#     379 try:
# --> 380     return FileDataContext(
#     381         project_config=project_config,
#     382         context_root_dir=context_root_dir,
#     383         project_root_dir=project_root_dir,
#     384         runtime_environment=runtime_environment,
#     385         user_agent_str=user_agent_str,
#     386     )
#     387 except gx_exceptions.ConfigNotFoundError:
#     388     logger.info("Could not find local file-backed GX project")
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/file_data_context.py:63, in FileDataContext.__init__(self, project_config, context_root_dir, project_root_dir, runtime_environment, user_agent_str)
#      57 self._context_root_directory = self._init_context_root_directory(
#      58     context_root_dir=context_root_dir,
#      59     project_root_dir=project_root_dir,
#      60 )
#      61 self._scaffold_project()
# ---> 63 self._project_config = self._init_project_config(project_config)
#      64 super().__init__(
#      65     context_root_dir=self._context_root_directory,
#      66     runtime_environment=runtime_environment,
#      67     user_agent_str=user_agent_str,
#      68 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/file_data_context.py:114, in FileDataContext._init_project_config(self, project_config)
#     112     project_config = FileDataContext.get_or_create_data_context_config(project_config)
#     113 else:
# --> 114     project_config = FileDataContext._load_file_backed_project_config(
#     115         context_root_directory=self._context_root_directory,
#     116     )
#     117 return project_config
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/file_data_context.py:209, in FileDataContext._load_file_backed_project_config(cls, context_root_directory)
#     206     raise gx_exceptions.ConfigNotFoundError()
#     208 try:
# --> 209     return DataContextConfig.from_commented_map(
#     210         commented_map=config_commented_map_from_yaml
#     211     )
#     212 except gx_exceptions.InvalidDataContextConfigError:  # noqa: TRY203 # FIXME CoP
#     213     # Just to be explicit about what we intended to catch
#     214     raise
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/types/base.py:127, in BaseYamlConfig.from_commented_map(cls, commented_map)
#     125 try:
#     126     schema_instance: Schema = cls._get_schema_instance()
# --> 127     config: Union[dict, BYC] = schema_instance.load(commented_map)
#     128     if isinstance(config, dict):
#     129         return cls.get_config_class()(commented_map=commented_map, **config)
#
# File ~/.local/lib/python3.10/site-packages/marshmallow/schema.py:792, in Schema.load(self, data, many, partial, unknown)
#     761 def load(
#     762     self,
#     763     data: (
#    (...)
#     770     unknown: str | None = None,
#     771 ):
#     772     """Deserialize a data structure to an object defined by this Schema's fields.
#     773
#     774     :param data: The data to deserialize.
#    (...)
#     790         if invalid data are passed.
#     791     """
# --> 792     return self._do_load(
#     793         data, many=many, partial=partial, unknown=unknown, postprocess=True
#     794     )
#
# File ~/.local/lib/python3.10/site-packages/marshmallow/schema.py:998, in Schema._do_load(self, data, many, partial, unknown, postprocess)
#     996 if errors:
#     997     exc = ValidationError(errors, data=data, valid_data=result)
# --> 998     self.handle_error(exc, data, many=many, partial=partial)
#     999     raise exc
#    1001 return result
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/types/base.py:1145, in DataContextConfigSchema.handle_error(self, exc, data, **kwargs)
#    1143 message: str = f"Error while processing DataContextConfig: {' '.join(exc.messages)}"
#    1144 logger.error(message)
# -> 1145 raise gx_exceptions.InvalidDataContextConfigError(
#    1146     message=message,
#    1147 )
#
# InvalidDataContextConfigError: Error while processing DataContextConfig: validation_operators notebooks evaluation_parameter_store_name validations_store_name datasources anonymous_usage_statistics

# %% [markdown]
# ### Task 2: Implement a Basic Alert System for Data Quality Drops
# **Description**: Set up a basic alert system that triggers when data quality drops.

# %%
# Write your code from here
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Write your code from here
#       2 import pandas as pd
# ----> 3 from great_expectations.core.expectation_configuration import ExpectationConfiguration
#       4 from great_expectations.data_context import DataContext
#       6 data = {
#       7     'age': [25, 30, 35, 40, 45, 200],
#       8     'income': [50000, 60000, 75000, None, 100000, -1000]
#       9 }
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/__init__.py:7
#       4 __version__ = get_versions()["version"]  # isort:skip
#       5 del get_versions  # isort:skip
# ----> 7 from great_expectations.data_context import DataContext
#       9 from .util import (
#      10     from_pandas,
#      11     measure_execution_time,
#    (...)
#      19     validate,
#      20 )
#      22 rtd_url_ge_version = __version__.replace(".", "_")
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/__init__.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 from .data_context import BaseDataContext, DataContext, ExplorerDataContext
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context.py:29
#      27 from great_expectations.core.id_dict import BatchKwargs
#      28 from great_expectations.core.metric import ValidationMetricIdentifier
# ---> 29 from great_expectations.core.usage_statistics.usage_statistics import (
#      30     UsageStatisticsHandler,
#      31     add_datasource_usage_statistics,
#      32     run_validation_operator_usage_statistics,
#      33     save_expectation_suite_usage_statistics,
#      34     usage_statistics_enabled_method,
#      35 )
#      36 from great_expectations.core.util import nested_update
#      37 from great_expectations.data_asset import DataAsset
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/core/usage_statistics/usage_statistics.py:21
#      17 from great_expectations.core.usage_statistics.anonymizers.anonymizer import Anonymizer
#      18 from great_expectations.core.usage_statistics.anonymizers.batch_anonymizer import (
#      19     BatchAnonymizer,
#      20 )
# ---> 21 from great_expectations.core.usage_statistics.anonymizers.data_docs_site_anonymizer import (
#      22     DataDocsSiteAnonymizer,
#      23 )
#      24 from great_expectations.core.usage_statistics.anonymizers.datasource_anonymizer import (
#      25     DatasourceAnonymizer,
#      26 )
#      27 from great_expectations.core.usage_statistics.anonymizers.expectation_suite_anonymizer import (
#      28     ExpectationSuiteAnonymizer,
#      29 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/core/usage_statistics/anonymizers/data_docs_site_anonymizer.py:2
#       1 from great_expectations.core.usage_statistics.anonymizers.anonymizer import Anonymizer
# ----> 2 from great_expectations.core.usage_statistics.anonymizers.site_builder_anonymizer import (
#       3     SiteBuilderAnonymizer,
#       4 )
#       5 from great_expectations.core.usage_statistics.anonymizers.store_backend_anonymizer import (
#       6     StoreBackendAnonymizer,
#       7 )
#      10 class DataDocsSiteAnonymizer(Anonymizer):
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/core/usage_statistics/anonymizers/site_builder_anonymizer.py:2
#       1 from great_expectations.core.usage_statistics.anonymizers.anonymizer import Anonymizer
# ----> 2 from great_expectations.render.renderer.site_builder import (
#       3     DefaultSiteIndexBuilder,
#       4     DefaultSiteSectionBuilder,
#       5     SiteBuilder,
#       6 )
#       9 class SiteBuilderAnonymizer(Anonymizer):
#      10     def __init__(self, salt=None):
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/render/__init__.py:1
# ----> 1 from .view import DefaultJinjaPageView
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/render/view/__init__.py:1
# ----> 1 from .view import (
#       2     DefaultJinjaComponentView,
#       3     DefaultJinjaIndexPageView,
#       4     DefaultJinjaPageView,
#       5     DefaultJinjaSectionView,
#       6     DefaultMarkdownPageView,
#       7 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/render/view/view.py:11
#       8 from uuid import uuid4
#      10 import mistune
# ---> 11 from jinja2 import (
#      12     ChoiceLoader,
#      13     Environment,
#      14     FileSystemLoader,
#      15     PackageLoader,
#      16     contextfilter,
#      17     select_autoescape,
#      18 )
#      20 from great_expectations import __version__ as ge_version
#      21 from great_expectations.render.types import (
#      22     RenderedComponentContent,
#      23     RenderedContent,
#      24     RenderedDocumentContent,
#      25 )
#
# ImportError: cannot import name 'contextfilter' from 'jinja2' (/home/vscode/.local/lib/python3.10/site-packages/jinja2/__init__.py)

# %% [markdown]
# ### Task 3: Real-time Data Quality Monitoring with Python and Great Expectations
# **Description**: Implement a system that monitors data quality in real-time.

# %%
# Write your code from here
